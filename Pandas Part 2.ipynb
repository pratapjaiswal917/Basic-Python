# %% [markdown]
# # Dealing with Duplicate Values in pandas

# %% [markdown]
# ## Import Library

# %%
import pandas as pd # # import library pandas

# %% [markdown]
# ## Reading Csv files in Pandas

# %%
df = pd.read_excel("C:/Users/prata/Downloads/restaurant.xlsx") #It will work if csv file in same folder

# %% [markdown]
# ## To Cheek data

# %%
df
# Out:
#             id                      name Country      city rating  \
# 0       567335            AB FOODS POINT   India    Abohar     --
# 1       531342         Janta Sweet House   India    Abohar    4.4
# 2       158203         theka coffee desi   India    Abohar    3.8
# 3       187912                 Singh Hut   India    Abohar    3.7
# 4       543530             GRILL MASTERS   India    Abohar     --
# ...        ...                       ...     ...       ...    ...
# 148535  553122          The Food Delight   India  Yavatmal     --
# 148536  562647  MAITRI FOODS & BEVERAGES   India  Yavatmal     --
# 148537  559435           Cafe Bella Ciao   India  Yavatmal     --
# 148538  418989               GRILL ZILLA   India  Yavatmal     --
# 148539  447770            Lazeez kitchen   India  Yavatmal     --
#
#            rating_count                     cuisine  \
# 0       Too Few Ratings            Beverages,Pizzas
# 1           50+ ratings               Sweets,Bakery
# ...

# %% [markdown]
# ## Find Duplicate in dataset

# %%
df.duplicated() # it will tell you about duplicate in dataset
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148535    False
# 148536    False
# 148537    False
# 148538    False
# 148539    False
# Length: 148540, dtype: bool

# %%
df["id"].duplicated() #you can cheek duplicate by passing "id" Column
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148535    False
# 148536    False
# 148537    False
# 148538    False
# 148539    False
# Name: id, Length: 148540, dtype: bool

# %%
df["id"].duplicated().sum() # we can cheek duplicate in column by sum
# Out:
# 0

# %%
df.drop_duplicates() # drop Duplicate
# Out:
#             id                      name Country      city rating  \
# 0       567335            AB FOODS POINT   India    Abohar     --
# 1       531342         Janta Sweet House   India    Abohar    4.4
# 2       158203         theka coffee desi   India    Abohar    3.8
# 3       187912                 Singh Hut   India    Abohar    3.7
# 4       543530             GRILL MASTERS   India    Abohar     --
# ...        ...                       ...     ...       ...    ...
# 148535  553122          The Food Delight   India  Yavatmal     --
# 148536  562647  MAITRI FOODS & BEVERAGES   India  Yavatmal     --
# 148537  559435           Cafe Bella Ciao   India  Yavatmal     --
# 148538  418989               GRILL ZILLA   India  Yavatmal     --
# 148539  447770            Lazeez kitchen   India  Yavatmal     --
#
#            rating_count                     cuisine  \
# 0       Too Few Ratings            Beverages,Pizzas
# 1           50+ ratings               Sweets,Bakery
# ...

# %%
df.drop_duplicates("id") # drop duplicate by column
# Out:
#             id                      name Country      city rating  \
# 0       567335            AB FOODS POINT   India    Abohar     --
# 1       531342         Janta Sweet House   India    Abohar    4.4
# 2       158203         theka coffee desi   India    Abohar    3.8
# 3       187912                 Singh Hut   India    Abohar    3.7
# 4       543530             GRILL MASTERS   India    Abohar     --
# ...        ...                       ...     ...       ...    ...
# 148535  553122          The Food Delight   India  Yavatmal     --
# 148536  562647  MAITRI FOODS & BEVERAGES   India  Yavatmal     --
# 148537  559435           Cafe Bella Ciao   India  Yavatmal     --
# 148538  418989               GRILL ZILLA   India  Yavatmal     --
# 148539  447770            Lazeez kitchen   India  Yavatmal     --
#
#            rating_count                     cuisine  \
# 0       Too Few Ratings            Beverages,Pizzas
# 1           50+ ratings               Sweets,Bakery
# ...
