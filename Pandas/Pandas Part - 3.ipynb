# %% [markdown]
# # Working with Missing Data in pandas

# %% [markdown]
# ## Import Library

# %%
import pandas as pd # import library pandas
import numpy as np # import library numpy

# %% [markdown]
# # Reading Csv files in Pandas

# %%
df = pd.read_excel("C:/Users/prata/Downloads/restaurant.xlsx") #It will work if csv file in same folder

# %%
df # to Cheek DataSet
# Out:
#             id                      name Country      city rating  \
# 0       567335            AB FOODS POINT   India    Abohar     --
# 1       531342         Janta Sweet House   India    Abohar    4.4
# 2       158203         theka coffee desi   India    Abohar    3.8
# 3       187912                 Singh Hut   India    Abohar    3.7
# 4       543530             GRILL MASTERS   India    Abohar     --
# ...        ...                       ...     ...       ...    ...
# 148535  553122          The Food Delight   India  Yavatmal     --
# 148536  562647  MAITRI FOODS & BEVERAGES   India  Yavatmal     --
# 148537  559435           Cafe Bella Ciao   India  Yavatmal     --
# 148538  418989               GRILL ZILLA   India  Yavatmal     --
# 148539  447770            Lazeez kitchen   India  Yavatmal     --
#
#            rating_count                     cuisine  \
# 0       Too Few Ratings            Beverages,Pizzas
# 1           50+ ratings               Sweets,Bakery
# ...

# %%
df.isnull() # To Cheek Nan Value
# Out:
#            id   name  Country   city  rating  rating_count  cuisine   link  \
# 0       False  False    False  False   False         False    False  False
# 1       False  False    False  False   False         False    False  False
# 2       False  False    False  False   False         False    False  False
# 3       False  False    False  False   False         False    False  False
# 4       False  False    False  False   False         False    False  False
# ...       ...    ...      ...    ...     ...           ...      ...    ...
# 148535  False  False    False  False   False         False    False  False
# 148536  False  False    False  False   False         False    False  False
# 148537  False  False    False  False   False         False    False  False
# 148538  False  False    False  False   False         False    False  False
# 148539  False  False    False  False   False         False    False  False
#
#         address
# 0         False
# 1         False
# ...

# %%
df.isnull().sum() # To Cheek Nan Value by column
# Out:
# id               0
# name            86
# Country          0
# city             0
# rating          86
# rating_count    86
# cuisine         99
# link             0
# address         86
# dtype: int64

# %%
df.dropna() # to drop nan Value
# Out:
#             id                      name Country      city rating  \
# 0       567335            AB FOODS POINT   India    Abohar     --
# 1       531342         Janta Sweet House   India    Abohar    4.4
# 2       158203         theka coffee desi   India    Abohar    3.8
# 3       187912                 Singh Hut   India    Abohar    3.7
# 4       543530             GRILL MASTERS   India    Abohar     --
# ...        ...                       ...     ...       ...    ...
# 148535  553122          The Food Delight   India  Yavatmal     --
# 148536  562647  MAITRI FOODS & BEVERAGES   India  Yavatmal     --
# 148537  559435           Cafe Bella Ciao   India  Yavatmal     --
# 148538  418989               GRILL ZILLA   India  Yavatmal     --
# 148539  447770            Lazeez kitchen   India  Yavatmal     --
#
#            rating_count                     cuisine  \
# 0       Too Few Ratings            Beverages,Pizzas
# 1           50+ ratings               Sweets,Bakery
# ...

# %%
df  #After droping Nan Value you can See the No of rows
# Out:
#             id                      name Country      city rating  \
# 0       567335            AB FOODS POINT   India    Abohar     --
# 1       531342         Janta Sweet House   India    Abohar    4.4
# 2       158203         theka coffee desi   India    Abohar    3.8
# 3       187912                 Singh Hut   India    Abohar    3.7
# 4       543530             GRILL MASTERS   India    Abohar     --
# ...        ...                       ...     ...       ...    ...
# 148535  553122          The Food Delight   India  Yavatmal     --
# 148536  562647  MAITRI FOODS & BEVERAGES   India  Yavatmal     --
# 148537  559435           Cafe Bella Ciao   India  Yavatmal     --
# 148538  418989               GRILL ZILLA   India  Yavatmal     --
# 148539  447770            Lazeez kitchen   India  Yavatmal     --
#
#            rating_count                     cuisine  \
# 0       Too Few Ratings            Beverages,Pizzas
# 1           50+ ratings               Sweets,Bakery
# ...

# %%
df.replace(np.nan,"")  # We Can replace Nan Value with any value

# %% [markdown]
# * For Replacing nan value from dataset first go through Client Conversetion after that we can make changes in dataset
# * if want to replace nan value then take mean() value then replace it with nan.

# %%
df["rating"] = df["rating"].replace(np.nan,3)  #replacing nan Value in column rating with 3

# %%
df
# Out:
#             id                      name Country      city rating  \
# 0       567335            AB FOODS POINT   India    Abohar     --
# 1       531342         Janta Sweet House   India    Abohar    4.4
# 2       158203         theka coffee desi   India    Abohar    3.8
# 3       187912                 Singh Hut   India    Abohar    3.7
# 4       543530             GRILL MASTERS   India    Abohar     --
# ...        ...                       ...     ...       ...    ...
# 148535  553122          The Food Delight   India  Yavatmal     --
# 148536  562647  MAITRI FOODS & BEVERAGES   India  Yavatmal     --
# 148537  559435           Cafe Bella Ciao   India  Yavatmal     --
# 148538  418989               GRILL ZILLA   India  Yavatmal     --
# 148539  447770            Lazeez kitchen   India  Yavatmal     --
#
#            rating_count                     cuisine  \
# 0       Too Few Ratings            Beverages,Pizzas
# 1           50+ ratings               Sweets,Bakery
# ...

# %%
df.isnull().sum() # To Cheek Nan Value by column now we can see that nan value is fully replaced now it is showing 0
# Out:
# id               0
# name            86
# Country          0
# city             0
# rating           0
# rating_count    86
# cuisine         99
# link             0
# address         86
# dtype: int64

# %%
df.fillna(method = "bfill") # to fill nan value with backward fill
# Out:
#             id                      name Country      city rating  \
# 0       567335            AB FOODS POINT   India    Abohar     --
# 1       531342         Janta Sweet House   India    Abohar    4.4
# 2       158203         theka coffee desi   India    Abohar    3.8
# 3       187912                 Singh Hut   India    Abohar    3.7
# 4       543530             GRILL MASTERS   India    Abohar     --
# ...        ...                       ...     ...       ...    ...
# 148535  553122          The Food Delight   India  Yavatmal     --
# 148536  562647  MAITRI FOODS & BEVERAGES   India  Yavatmal     --
# 148537  559435           Cafe Bella Ciao   India  Yavatmal     --
# 148538  418989               GRILL ZILLA   India  Yavatmal     --
# 148539  447770            Lazeez kitchen   India  Yavatmal     --
#
#            rating_count                     cuisine  \
# 0       Too Few Ratings            Beverages,Pizzas
# 1           50+ ratings               Sweets,Bakery
# ...

# %%
df.fillna(method = "bfill") # to fill nan value with forward fill
# Out:
#             id                      name Country      city rating  \
# 0       567335            AB FOODS POINT   India    Abohar     --
# 1       531342         Janta Sweet House   India    Abohar    4.4
# 2       158203         theka coffee desi   India    Abohar    3.8
# 3       187912                 Singh Hut   India    Abohar    3.7
# 4       543530             GRILL MASTERS   India    Abohar     --
# ...        ...                       ...     ...       ...    ...
# 148535  553122          The Food Delight   India  Yavatmal     --
# 148536  562647  MAITRI FOODS & BEVERAGES   India  Yavatmal     --
# 148537  559435           Cafe Bella Ciao   India  Yavatmal     --
# 148538  418989               GRILL ZILLA   India  Yavatmal     --
# 148539  447770            Lazeez kitchen   India  Yavatmal     --
#
#            rating_count                     cuisine  \
# 0       Too Few Ratings            Beverages,Pizzas
# 1           50+ ratings               Sweets,Bakery
# ...
